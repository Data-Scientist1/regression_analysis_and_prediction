# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# ## loading the data

# %%
df_mat = pd.read_csv('student-mat.csv', delimiter=';')

# %%
df_mat.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ## Data Cleaning

# %%
df_mat.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# ## Data processing

# %%
obj_columns = [x for x in df_mat.columns if df_mat[x].dtype == "object"]
int_columns = [x for x in df_mat.columns if df_mat[x].dtype != "object"]
int_columns = int_columns[:-1]

# %%
for i in int_columns:
    df_mat[i] = (df_mat[i] - df_mat[i].mean()) / df_mat[i].std()

# %%
train, train_target = df_mat.iloc[:, :-3], df_mat.iloc[:,-1]

# %%
train = pd.get_dummies(train, dummy_na=True)

# %%
train
# Out:
#           age      Medu      Fedu  traveltime  studytime  failures    famrel  \
# 0    1.021751  1.142407  1.358648    0.791247  -0.042232 -0.449374  0.062115
# 1    0.238078 -1.597982 -1.398197   -0.642435  -0.042232 -0.449374  1.177367
# 2   -1.329268 -1.597982 -1.398197   -0.642435  -0.042232  3.584777  0.062115
# 3   -1.329268  1.142407 -0.479249   -0.642435   1.149321 -0.449374 -1.053136
# 4   -0.545595  0.228944  0.439699   -0.642435  -0.042232 -0.449374  0.062115
# ..        ...       ...       ...         ...        ...       ...       ...
# 390  2.589096 -0.684519 -0.479249   -0.642435  -0.042232  2.240060  1.177367
# 391  0.238078  0.228944 -1.398197    0.791247  -1.233786 -0.449374 -2.168388
# 392  3.372769 -1.597982 -1.398197   -0.642435  -1.233786  3.584777  1.177367
# 393  1.021751  0.228944 -0.479249    2.224929  -1.233786 -0.449374  0.062115
# 394  1.805423 -1.597982 -1.398197   -0.642435  -1.233786 -0.449374 -1.053136
#
# ...

# %% [markdown]
# ## Finding the best model

# %% [markdown]
# ### Using Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
d_reg = DecisionTreeRegressor()
d_reg.fit(train, train_target)
# Out:
# DecisionTreeRegressor()

# %%
d_reg.score(train, train_target)
# Out:
# 1.0

# %% [markdown]
# ### Using SGDRegressor

# %%
from sklearn.linear_model import SGDRegressor

# %%
s_reg = SGDRegressor()
s_reg.fit(train, train_target)
# Out:
# SGDRegressor()

# %%
s_reg.score(train, train_target)
# Out:
# 0.2713816555309255

# %% [markdown]
# ### Using Random forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
r_reg = RandomForestRegressor()
r_reg.fit(train, train_target)
# Out:
# RandomForestRegressor()

# %%
r_reg.score(train, train_target)
# Out:
# 0.8989812446465973
